# %% [markdown]
# # **Vehicle Trajectory Prediction**

# %% [markdown]
# https://journals.sagepub.com/doi/abs/10.1177/0361198121993471

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **NVIDIA GPU 환경 확인**

# %%
# !nvidia-smi

# %% [markdown]
# ## **실습 코드 실행을 위한 PyTorch 버전 다운그레이드 진행**

# %%
# !pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 torchaudio==0.11.0 --extra-index-url https://download.pytorch.org/whl/cu113

# %% [markdown]
# ### **PyTorch 버전 확인**

# %%
import torch

# %%
torch.__version__

# %% [markdown]
# ## **GitHub Repository Clone 진행**

# %%
# !git clone https://github.com/jetsonai/LSTMTracking.git

# %% [markdown]
# ## **Clone한 Directory로 경로 이동**

# %%
# %cd /content/LSTMTracking/04_Vehicle_Trajectory_Prediction

# %% [markdown]
# ## **경로 내 존재하는 폴더 및 파일 출력**

# %%
# !ls

# %% [markdown]
# ## **데이터셋 저장을 위한 폴더 생성**

# %%
# %mkdir -p data/trajectory

# %% [markdown]
# ### **경로 내 존재하는 폴더 및 파일 출력**

# %%
# !ls

# %% [markdown]
# ## **데이터셋 압축 해제**

# %%
# !unzip "/content/LSTMTracking/dataset/vehicle-trajectory-prediction.zip" -d "/content/LSTMTracking/04_Vehicle_Trajectory_Prediction/data/trajectory"

# %% [markdown]
# ### **압축 해제 결과 확인**

# %%
# !ls data/trajectory

# %% [markdown]
# ## **모델 훈련을 위한 hdf5storage 라이브러리 설치**

# %%
# !pip install hdf5storage

# %% [markdown]
# ## **훈련 코드 실행**

# %%
# !python train.py

# %% [markdown]
# ## **모델 성능 평가 코드 실행**

# %%
# !python evaluate.py
