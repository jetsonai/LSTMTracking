# %% [markdown]
# # **RNN / LSTM / GRU를 활용한 이미지 분류 (MNIST 데이터셋)**

# %% [markdown]
# ## MNIST 데이터셋 이미지

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 이미지를 Time Sequence로 바라보고 RNN를 적용

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **PyTorch 라이브러리 불러오기**

# %%
import torch
from torch import nn

# %% [markdown]
# ## **Torchvision 라이브러리 불러오기**

# %%
import torchvision
from torchvision import transforms

# %% [markdown]
# ## **MNIST 데이터셋 불러오기**

# %%
trainDataset = torchvision.datasets.MNIST(root="/data",
                                          train=True,
                                          transform=transforms.ToTensor(),
                                          download=True)
testDataset = torchvision.datasets.MNIST(root="/data",
                                         train=False,
                                         transform=transforms.ToTensor())

# %% [markdown]
# ## **훈련 및 모델 하이퍼파라미터 선정**

# %%
opt = {"seqLen":28, "inputSize":28, "hiddenSize":128, "numLayer":1,
       "numClass":10, "batchSize":128, "numEpoch":20, "lr":1e-3, "seed":42}

# %% [markdown]
# ## **Seed 고정**

# %%
import random
import numpy as np

# %%
def fixSeed(seed) :
  random.seed(seed)
  np.random.seed(seed)
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = False

# %%
fixSeed(opt["seed"])

# %% [markdown]
# ## **사용 Device 정하기 (GPU 또는 CPU)**

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
print(f"Device Type : {device}")

# %% [markdown]
# ## **DataLoader 생성**

# %%
trainLoader = torch.utils.data.DataLoader(trainDataset,
                                          batch_size=opt["batchSize"],
                                          drop_last=True,
                                          shuffle=True)

testLoader = torch.utils.data.DataLoader(testDataset,
                                         batch_size=opt["batchSize"],
                                         drop_last=False,
                                         shuffle=False)

# %% [markdown]
# ## **RNN**

# %% [markdown]
# ### PyTorch RNN

# %% [markdown]
# https://pytorch.org/docs/stable/generated/torch.nn.RNN.html#torch.nn.RNN

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **RNN 모델 클래스 정의**

# %% [markdown]
# #### Many-to-Many 유형

# %%
class RNN(nn.Module) :
    def __init__(self, inputSize, hiddenSize, numLayer, numClass) :
        # Inheritance
        super(RNN, self).__init__()

        # Initialize Variables
        self.hiddenSize = hiddenSize
        self.numLayer = numLayer
        self.rnn = nn.RNN(inputSize, hiddenSize, numLayer, batch_first=True)
        self.fc = nn.Linear(hiddenSize, numClass)

    def forward(self, input) :
        # Input Shape → (batchSize, length, inputSize)
        # 최초의 Hidden State → 초기화
        # 만약 Bi-Directional LSTM이라면 아래의 Hidden Stated의 첫번째 차원은 2*self.numLayer
        h0 = torch.zeros(self.numLayer, input.size(0), self.hiddenSize).to(input.device)

        # LSTM 순전파
        output, _ = self.rnn(input, h0) # output : (batch, length, hiddenSize) | hn은 필요 없음으로 _로 Return

        # 마지막 Time Step (Sequence Length)의 Hidden State를 사용해 Class들의 Logit을 반환 (hiddenSize → numClass)
        output = self.fc(output[:, -1, :])

        return output

# %% [markdown]
# ### **훈련 과정 요약을 위한 Average Meter 인스턴스 생성**

# %%
class AverageMeter(object) :
  def __init__(self) :
    self.reset()

  def reset(self) :
    self.val = 0
    self.avg = 0
    self.sum = 0
    self.count = 0

  def update(self, val, n=1) :
    self.val = val
    self.sum += val*n
    self.count += n
    self.avg = self.sum / self.count

# %%
trainLoss, testLoss = AverageMeter(), AverageMeter()

# %%
trainAcc, testAcc = AverageMeter(), AverageMeter()

# %% [markdown]
# ### **훈련 결과 저장을 위한 Python List 인스턴스 생성**

# %%
rnnTrainLossList, rnnTestLossList = [], []

# %%
rnnTrainAccList, rnnTestAccList = [], []

# %%
bestTestAcc = 0

# %% [markdown]
# ### **RNN 모델 훈련**

# %% [markdown]
# #### **RNN 모델 인스턴스 생성**

# %%
fixSeed(opt["seed"])

# %%
model = RNN(opt["inputSize"], opt["hiddenSize"], opt["numLayer"], opt["numClass"]).to(device)

# %% [markdown]
# #### **RNN 모델 파라미터 개수 계산**

# %%
numParameter = sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f"Number of Trainable Parameters : {numParameter:,}")

# %% [markdown]
# #### **손실 함수 인스턴스 생성**

# %%
criterion = nn.CrossEntropyLoss()

# %% [markdown]
# #### **Optimizer 인스턴스 생성**

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=opt["lr"])

# %% [markdown]
# ### **정확도 계산을 위한 torchmetrics 라이브러리 설치**

# %%
# !pip install torchmetrics

# %%
from torchmetrics import Accuracy

# %%
accuracy = Accuracy(task="multiclass", num_classes=opt["numClass"]).to(device)

# %% [markdown]
# #### **훈련 진행**

# %% [markdown]
# ##### Progress Bar 시각화를 위한 TQDM 라이브러리 불러오기

# %%
from tqdm import tqdm

# %%
for epoch in range(1, opt["numEpoch"]+1) :
  ########################################################################################################################################

    trainBar = tqdm(trainLoader) # Create TQDM Instance
    trainLoss.reset(), trainAcc.reset() # Reset AverageMeter Instance

    model.train() # Train Mode

    for data in trainBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      optimizer.zero_grad() # Set Gradient to 0
      pred = model(images) # Get Prediction
      loss = criterion(pred, labels) # Compute Loss
      loss.backward() # Back-Propagation
      optimizer.step() # Update Weight

      trainLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
      trainAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
      trainBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Train] < Loss:{trainLoss.avg:.4f} | Accuracy:{trainAcc.avg:.4f} >")

    rnnTrainLossList.append(trainLoss.avg), rnnTrainAccList.append(trainAcc.avg)

    ########################################################################################################################################

    testBar = tqdm(testLoader) # Create TQDM Instance
    testLoss.reset(), testAcc.reset() # Reset AverageMeter Instance

    model.eval() # Evaulation Mode

    for data in testBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      with torch.no_grad() :
        pred = model(images) # Get Prediction
        loss = criterion(pred, labels) # Compute Loss

        testLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
        testAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
        testBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Test] < Loss:{testLoss.avg:.4f} | Accuracy:{testAcc.avg:.4f} >")

    rnnTestLossList.append(testLoss.avg), rnnTestAccList.append(testAcc.avg)

    if testAcc.avg > bestTestAcc :
      bestTestAcc = testAcc.avg
      torch.save(model.state_dict(), "Best-RNN.pth")

    torch.save(model.state_dict(), "Latest-RNN.pth")

# %%
print(f"Best Test Accuracy : {bestTestAcc:.4f}")

# %% [markdown]
# ### **RNN 모델 훈련 과정 시각화**

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.arange(opt["numEpoch"]), rnnTrainLossList, label="Train Loss")
plt.plot(np.arange(opt["numEpoch"]), rnnTestLossList, label="Test Loss")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("CE Loss")
plt.title("[RNN] Train Loss vs. Test Loss")
plt.show()

# %%
plt.plot(np.arange(opt["numEpoch"]), rnnTrainAccList, label="Train Accuracy")
plt.plot(np.arange(opt["numEpoch"]), rnnTestAccList, label="Test Accuracy")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("[RNN] Train Accuracy vs. Test Accuracy")
plt.show()

# %% [markdown]
# ## **LSTM**

# %% [markdown]
# ### PyTorch LSTM

# %% [markdown]
# https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **LSTM 모델 클래스 정의**

# %% [markdown]
# #### Many-to-Many 유형

# %%
class LSTM(nn.Module) :
    def __init__(self, inputSize, hiddenSize, numLayer, numClass) :
        # Inheritance
        super(LSTM, self).__init__()

        # Initialize Variables
        self.hiddenSize = hiddenSize
        self.numLayer = numLayer
        self.lstm = nn.LSTM(inputSize, hiddenSize, numLayer, batch_first=True)
        self.fc = nn.Linear(hiddenSize, numClass)

    def forward(self, input) :
        # Input Shape → (batchSize, length, inputSize)
        # 최초의 Hidden State와 Cell State → 초기화
        # 만약 Bi-Directional LSTM이라면 아래의 Hidden Stated와 Cell State의 첫번째 차원은 2*self.numLayer
        h0 = torch.zeros(self.numLayer, input.size(0), self.hiddenSize).to(input.device)
        c0 = torch.zeros(self.numLayer, input.size(0), self.hiddenSize).to(input.device)

        # LSTM 순전파
        output, _ = self.lstm(input, (h0, c0)) # output : (batch, length, hiddenSize) | (hn, cn)은 필요 없음으로 _로 Return

        # 마지막 Time Step (Sequence Length)의 Hidden State를 사용해 Class들의 Logit을 반환 (hiddenSize → numClass)
        output = self.fc(output[:, -1, :])

        return output

# %% [markdown]
# ### **훈련 결과 저장을 위한 Python List 인스턴스 생성**

# %%
lstmTrainLossList, lstmTestLossList = [], []

# %%
lstmTrainAccList, lstmTestAccList = [], []

# %%
bestTestAcc = 0

# %% [markdown]
# ### **LSTM 모델 훈련**

# %% [markdown]
# #### **LSTM 모델 인스턴스 생성**

# %%
fixSeed(opt["seed"])

# %%
model = LSTM(opt["inputSize"], opt["hiddenSize"], opt["numLayer"], opt["numClass"]).to(device)

# %% [markdown]
# #### **LSTM 모델 파라미터 개수 계산**

# %%
numParameter = sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f"Number of Trainable Parameters : {numParameter:,}")

# %% [markdown]
# #### **Optimizer 인스턴스 생성**

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=opt["lr"])

# %% [markdown]
# #### **훈련 진행**

# %%
for epoch in range(1, opt["numEpoch"]+1) :
  ########################################################################################################################################

    trainBar = tqdm(trainLoader) # Create TQDM Instance
    trainLoss.reset(), trainAcc.reset() # Reset AverageMeter Instance

    model.train() # Train Mode

    for data in trainBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      optimizer.zero_grad() # Set Gradient to 0
      pred = model(images) # Get Prediction
      loss = criterion(pred, labels) # Compute Loss
      loss.backward() # Back-Propagation
      optimizer.step() # Update Weight

      trainLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
      trainAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
      trainBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Train] < Loss:{trainLoss.avg:.4f} | Accuracy:{trainAcc.avg:.4f} >")

    lstmTrainLossList.append(trainLoss.avg), lstmTrainAccList.append(trainAcc.avg)

    ########################################################################################################################################

    testBar = tqdm(testLoader) # Create TQDM Instance
    testLoss.reset(), testAcc.reset() # Reset AverageMeter Instance

    model.eval() # Evaulation Mode

    for data in testBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      with torch.no_grad() :
        pred = model(images) # Get Prediction
        loss = criterion(pred, labels) # Compute Loss

        testLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
        testAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
        testBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Test] < Loss:{testLoss.avg:.4f} | Accuracy:{testAcc.avg:.4f} >")

    lstmTestLossList.append(testLoss.avg), lstmTestAccList.append(testAcc.avg)

    if testAcc.avg > bestTestAcc :
      bestTestAcc = testAcc.avg
      torch.save(model.state_dict(), "Best-LSTM.pth")

    torch.save(model.state_dict(), "Latest-LSTM.pth")

# %%
print(f"Best Test Accuracy : {bestTestAcc:.4f}")

# %% [markdown]
# ### **LSTM 모델 훈련 과정 시각화**

# %%
plt.plot(np.arange(opt["numEpoch"]), lstmTrainLossList, label="Train Loss")
plt.plot(np.arange(opt["numEpoch"]), lstmTestLossList, label="Test Loss")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("CE Loss")
plt.title("[LSTM] Train Loss vs. Test Loss")
plt.show()

# %%
plt.plot(np.arange(opt["numEpoch"]), lstmTrainAccList, label="Train Accuracy")
plt.plot(np.arange(opt["numEpoch"]), lstmTestAccList, label="Test Accuracy")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("[LSTM] Train Accuracy vs. Test Accuracy")
plt.show()

# %% [markdown]
# ## **GRU**

# %% [markdown]
# ### PyTorch GRU

# %% [markdown]
# https://pytorch.org/docs/stable/generated/torch.nn.LSTM.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### **GRU 모델 클래스 정의**

# %% [markdown]
# #### Many-to-Many 유형

# %%
class GRU(nn.Module) :
    def __init__(self, inputSize, hiddenSize, numLayer, numClass) :
        # Inheritance
        super(GRU, self).__init__()

        # Initialize Variables
        self.hiddenSize = hiddenSize
        self.numLayer = numLayer
        self.gru = nn.GRU(inputSize, hiddenSize, numLayer, batch_first=True)
        self.fc = nn.Linear(hiddenSize, numClass)

    def forward(self, input) :
        # Input Shape → (batchSize, length, inputSize)
        # 최초의 Hidden State → 초기화
        # 만약 Bi-Directional LSTM이라면 아래의 Hidden Stated의 첫번째 차원은 2*self.numLayer
        h0 = torch.zeros(self.numLayer, input.size(0), self.hiddenSize).to(input.device)

        # LSTM 순전파
        output, _ = self.gru(input, h0) # output : (batch, length, hiddenSize) | hn은 필요 없음으로 _로 Return

        # 마지막 Time Step (Sequence Length)의 Hidden State를 사용해 Class들의 Logit을 반환 (hiddenSize → numClass)
        output = self.fc(output[:, -1, :])

        return output

# %% [markdown]
# ### **훈련 결과 저장을 위한 Python List 인스턴스 생성**

# %%
gruTrainLossList, gruTestLossList = [], []

# %%
gruTrainAccList, gruTestAccList = [], []

# %%
bestTestAcc = 0

# %% [markdown]
# ### **GRU 모델 훈련**

# %% [markdown]
# #### **GRU 모델 인스턴스 생성**

# %%
fixSeed(opt["seed"])

# %%
model = GRU(opt["inputSize"], opt["hiddenSize"], opt["numLayer"], opt["numClass"]).to(device)

# %% [markdown]
# #### **GRU 모델 파라미터 개수 계산**

# %%
numParameter = sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f"Number of Trainable Parameters : {numParameter:,}")

# %% [markdown]
# #### **Optimizer 인스턴스 생성**

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=opt["lr"])

# %% [markdown]
# #### **훈련 진행**

# %%
for epoch in range(1, opt["numEpoch"]+1) :
  ########################################################################################################################################

    trainBar = tqdm(trainLoader) # Create TQDM Instance
    trainLoss.reset(), trainAcc.reset() # Reset AverageMeter Instance

    model.train() # Train Mode

    for data in trainBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      optimizer.zero_grad() # Set Gradient to 0
      pred = model(images) # Get Prediction
      loss = criterion(pred, labels) # Compute Loss
      loss.backward() # Back-Propagation
      optimizer.step() # Update Weight

      trainLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
      trainAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
      trainBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Train] < Loss:{trainLoss.avg:.4f} | Accuracy:{trainAcc.avg:.4f} >")

    gruTrainLossList.append(trainLoss.avg), gruTrainAccList.append(trainAcc.avg)

    ########################################################################################################################################

    testBar = tqdm(testLoader) # Create TQDM Instance
    testLoss.reset(), testAcc.reset() # Reset AverageMeter Instance

    model.eval() # Evaulation Mode

    for data in testBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      with torch.no_grad() :
        pred = model(images) # Get Prediction
        loss = criterion(pred, labels) # Compute Loss

        testLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
        testAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
        testBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Test] < Loss:{testLoss.avg:.4f} | Accuracy:{testAcc.avg:.4f} >")

    gruTestLossList.append(testLoss.avg), gruTestAccList.append(testAcc.avg)

    if testAcc.avg > bestTestAcc :
      bestTestAcc = testAcc.avg
      torch.save(model.state_dict(), "Best-GRU.pth")

    torch.save(model.state_dict(), "Latest-GRU.pth")

# %%
print(f"Best Test Accuracy : {bestTestAcc:.4f}")

# %% [markdown]
# ### **GRU 모델 훈련 과정 시각화**

# %%
plt.plot(np.arange(opt["numEpoch"]), gruTrainLossList, label="Train Loss")
plt.plot(np.arange(opt["numEpoch"]), gruTestLossList, label="Test Loss")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("CE Loss")
plt.title("[GRU] Train Loss vs. Test Loss")
plt.show()

# %%
plt.plot(np.arange(opt["numEpoch"]), gruTrainAccList, label="Train Accuracy")
plt.plot(np.arange(opt["numEpoch"]), gruTestAccList, label="Test Accuracy")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("[GRU] Train Accuracy vs. Test Accuracy")
plt.show()

# %% [markdown]
# ## **RNN vs. LSTM vs. GRU 성능 비교**

# %%
plt.plot(np.arange(opt["numEpoch"]), rnnTestLossList, label="Test Loss (RNN)")
plt.plot(np.arange(opt["numEpoch"]), lstmTestLossList, label="Test Loss (LSTM)")
plt.plot(np.arange(opt["numEpoch"]), gruTestLossList, label="Test Loss (GRU)")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("CE Loss")
plt.title("[Test Loss] RNN vs. LSTM vs. GRU")
plt.show()

# %%
plt.plot(np.arange(opt["numEpoch"]), rnnTestAccList, label="Test Accuracy (RNN)")
plt.plot(np.arange(opt["numEpoch"]), lstmTestAccList, label="Test Accuracy (LSTM)")
plt.plot(np.arange(opt["numEpoch"]), gruTestAccList, label="Test Accuracy (GRU)")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("[Test Accuracy] RNN vs. LSTM vs. GRU")
plt.show()

# %% [markdown]
# ## **Multi-Layer RNN**

# %% [markdown]
# ### **Stacked RNN 구현**

# %%
opt["numLayer"] = 5

# %% [markdown]
# ### **훈련 결과 저장을 위한 Python List 인스턴스 생성**

# %%
rnnTrainLossList, rnnTestLossList = [], []

# %%
rnnTrainAccList, rnnTestAccList = [], []

# %%
bestTestAcc = 0

# %% [markdown]
# #### **RNN 모델 인스턴스 생성**

# %%
fixSeed(opt["seed"])

# %%
model = RNN(opt["inputSize"], opt["hiddenSize"], opt["numLayer"], opt["numClass"]).to(device)

# %% [markdown]
# #### **RNN 모델 파라미터 개수 계산**

# %%
numParameter = sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f"Number of Trainable Parameters : {numParameter:,}")

# %% [markdown]
# #### **Optimizer 인스턴스 생성**

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=opt["lr"])

# %% [markdown]
# #### **훈련 진행**

# %%
for epoch in range(1, opt["numEpoch"]+1) :
  ########################################################################################################################################

    trainBar = tqdm(trainLoader) # Create TQDM Instance
    trainLoss.reset(), trainAcc.reset() # Reset AverageMeter Instance

    model.train() # Train Mode

    for data in trainBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      optimizer.zero_grad() # Set Gradient to 0
      pred = model(images) # Get Prediction
      loss = criterion(pred, labels) # Compute Loss
      loss.backward() # Back-Propagation
      optimizer.step() # Update Weight

      trainLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
      trainAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
      trainBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Train] < Loss:{trainLoss.avg:.4f} | Accuracy:{trainAcc.avg:.4f} >")

    rnnTrainLossList.append(trainLoss.avg), rnnTrainAccList.append(trainAcc.avg)

    ########################################################################################################################################

    testBar = tqdm(testLoader) # Create TQDM Instance
    testLoss.reset(), testAcc.reset() # Reset AverageMeter Instance

    model.eval() # Evaulation Mode

    for data in testBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      with torch.no_grad() :
        pred = model(images) # Get Prediction
        loss = criterion(pred, labels) # Compute Loss

        testLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
        testAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
        testBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Test] < Loss:{testLoss.avg:.4f} | Accuracy:{testAcc.avg:.4f} >")

    rnnTestLossList.append(testLoss.avg), rnnTestAccList.append(testAcc.avg)

    if testAcc.avg > bestTestAcc :
      bestTestAcc = testAcc.avg
      torch.save(model.state_dict(), "Best-RNN.pth")

    torch.save(model.state_dict(), "Latest-RNN.pth")

# %%
print(f"Best Test Accuracy : {bestTestAcc:.4f}")

# %% [markdown]
# ### **RNN 모델 훈련 과정 시각화**

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(np.arange(opt["numEpoch"]), rnnTrainLossList, label="Train Loss")
plt.plot(np.arange(opt["numEpoch"]), rnnTestLossList, label="Test Loss")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("CE Loss")
plt.title("[RNN] Train Loss vs. Test Loss")
plt.show()

# %%
plt.plot(np.arange(opt["numEpoch"]), rnnTrainAccList, label="Train Accuracy")
plt.plot(np.arange(opt["numEpoch"]), rnnTestAccList, label="Test Accuracy")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("[RNN] Train Accuracy vs. Test Accuracy")
plt.show()

# %% [markdown]
# ## **Multi-Layer LSTM**

# %% [markdown]
# ### **훈련 결과 저장을 위한 Python List 인스턴스 생성**

# %%
lstmTrainLossList, lstmTestLossList = [], []

# %%
lstmTrainAccList, lstmTestAccList = [], []

# %%
bestTestAcc = 0

# %% [markdown]
# #### **LSTM 모델 인스턴스 생성**

# %%
fixSeed(opt["seed"])

# %%
model = LSTM(opt["inputSize"], opt["hiddenSize"], opt["numLayer"], opt["numClass"]).to(device)

# %% [markdown]
# #### **LSTM 모델 파라미터 개수 계산**

# %%
numParameter = sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f"Number of Trainable Parameters : {numParameter:,}")

# %% [markdown]
# #### **Optimizer 인스턴스 생성**

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=opt["lr"])

# %% [markdown]
# #### **훈련 진행**

# %%
for epoch in range(1, opt["numEpoch"]+1) :
  ########################################################################################################################################

    trainBar = tqdm(trainLoader) # Create TQDM Instance
    trainLoss.reset(), trainAcc.reset() # Reset AverageMeter Instance

    model.train() # Train Mode

    for data in trainBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      optimizer.zero_grad() # Set Gradient to 0
      pred = model(images) # Get Prediction
      loss = criterion(pred, labels) # Compute Loss
      loss.backward() # Back-Propagation
      optimizer.step() # Update Weight

      trainLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
      trainAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
      trainBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Train] < Loss:{trainLoss.avg:.4f} | Accuracy:{trainAcc.avg:.4f} >")

    lstmTrainLossList.append(trainLoss.avg), lstmTrainAccList.append(trainAcc.avg)

    ########################################################################################################################################

    testBar = tqdm(testLoader) # Create TQDM Instance
    testLoss.reset(), testAcc.reset() # Reset AverageMeter Instance

    model.eval() # Evaulation Mode

    for data in testBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      with torch.no_grad() :
        pred = model(images) # Get Prediction
        loss = criterion(pred, labels) # Compute Loss

        testLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
        testAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
        testBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Test] < Loss:{testLoss.avg:.4f} | Accuracy:{testAcc.avg:.4f} >")

    lstmTestLossList.append(testLoss.avg), lstmTestAccList.append(testAcc.avg)

    if testAcc.avg > bestTestAcc :
      bestTestAcc = testAcc.avg
      torch.save(model.state_dict(), "Best-LSTM.pth")

    torch.save(model.state_dict(), "Latest-LSTM.pth")

# %%
print(f"Best Test Accuracy : {bestTestAcc:.4f}")

# %% [markdown]
# ### **LSTM 모델 훈련 과정 시각화**

# %%
plt.plot(np.arange(opt["numEpoch"]), lstmTrainLossList, label="Train Loss")
plt.plot(np.arange(opt["numEpoch"]), lstmTestLossList, label="Test Loss")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("CE Loss")
plt.title("[LSTM] Train Loss vs. Test Loss")
plt.show()

# %%
plt.plot(np.arange(opt["numEpoch"]), lstmTrainAccList, label="Train Accuracy")
plt.plot(np.arange(opt["numEpoch"]), lstmTestAccList, label="Test Accuracy")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("[LSTM] Train Accuracy vs. Test Accuracy")
plt.show()

# %% [markdown]
# ## **Multi-Layer GRU**

# %% [markdown]
# ### **훈련 결과 저장을 위한 Python List 인스턴스 생성**

# %%
gruTrainLossList, gruTestLossList = [], []

# %%
gruTrainAccList, gruTestAccList = [], []

# %%
bestTestAcc = 0

# %% [markdown]
# #### **GRU 모델 인스턴스 생성**

# %%
fixSeed(opt["seed"])

# %%
model = GRU(opt["inputSize"], opt["hiddenSize"], opt["numLayer"], opt["numClass"]).to(device)

# %% [markdown]
# #### **GRU 모델 파라미터 개수 계산**

# %%
numParameter = sum(p.numel() for p in model.parameters() if p.requires_grad)

# %%
print(f"Number of Trainable Parameters : {numParameter:,}")

# %% [markdown]
# #### **Optimizer 인스턴스 생성**

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=opt["lr"])

# %% [markdown]
# #### **훈련 진행**

# %%
for epoch in range(1, opt["numEpoch"]+1) :
  ########################################################################################################################################

    trainBar = tqdm(trainLoader) # Create TQDM Instance
    trainLoss.reset(), trainAcc.reset() # Reset AverageMeter Instance

    model.train() # Train Mode

    for data in trainBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      optimizer.zero_grad() # Set Gradient to 0
      pred = model(images) # Get Prediction
      loss = criterion(pred, labels) # Compute Loss
      loss.backward() # Back-Propagation
      optimizer.step() # Update Weight

      trainLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
      trainAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
      trainBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Train] < Loss:{trainLoss.avg:.4f} | Accuracy:{trainAcc.avg:.4f} >")

    gruTrainLossList.append(trainLoss.avg), gruTrainAccList.append(trainAcc.avg)

    ########################################################################################################################################

    testBar = tqdm(testLoader) # Create TQDM Instance
    testLoss.reset(), testAcc.reset() # Reset AverageMeter Instance

    model.eval() # Evaulation Mode

    for data in testBar :
      images, labels = data # Unpack Tuple Elements
      images, labels = images.to(device), labels.to(device) # Assign Device
      images = images.reshape(-1, opt["seqLen"], opt["inputSize"]) # (batchSize, 1, 28, 28) → (batchSize, 28, 28)

      with torch.no_grad() :
        pred = model(images) # Get Prediction
        loss = criterion(pred, labels) # Compute Loss

        testLoss.update(loss.detach().cpu().item(), opt["batchSize"]) # Compute Averaged Loss
        testAcc.update(accuracy(pred, labels).detach().cpu().item(), opt["batchSize"]) # Compute Averaged Accuracy
        testBar.set_description(desc=f"[{epoch}/{opt['numEpoch']}] [Test] < Loss:{testLoss.avg:.4f} | Accuracy:{testAcc.avg:.4f} >")

    gruTestLossList.append(testLoss.avg), gruTestAccList.append(testAcc.avg)

    if testAcc.avg > bestTestAcc :
      bestTestAcc = testAcc.avg
      torch.save(model.state_dict(), "Best-GRU.pth")

    torch.save(model.state_dict(), "Latest-GRU.pth")

# %%
print(f"Best Test Accuracy : {bestTestAcc:.4f}")

# %% [markdown]
# ### **GRU 모델 훈련 과정 시각화**

# %%
plt.plot(np.arange(opt["numEpoch"]), gruTrainLossList, label="Train Loss")
plt.plot(np.arange(opt["numEpoch"]), gruTestLossList, label="Test Loss")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("CE Loss")
plt.title("[GRU] Train Loss vs. Test Loss")
plt.show()

# %%
plt.plot(np.arange(opt["numEpoch"]), gruTrainAccList, label="Train Accuracy")
plt.plot(np.arange(opt["numEpoch"]), gruTestAccList, label="Test Accuracy")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("[GRU] Train Accuracy vs. Test Accuracy")
plt.show()

# %% [markdown]
# ## **RNN vs. LSTM vs.GRU 성능 비교**

# %%
plt.plot(np.arange(opt["numEpoch"]), rnnTestLossList, label="Test Loss (RNN)")
plt.plot(np.arange(opt["numEpoch"]), lstmTestLossList, label="Test Loss (LSTM)")
plt.plot(np.arange(opt["numEpoch"]), gruTestLossList, label="Test Loss (GRU)")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("CE Loss")
plt.title("[Test Loss] RNN vs. LSTM vs. GRU")
plt.show()

# %%
plt.plot(np.arange(opt["numEpoch"]), rnnTestAccList, label="Test Accuracy (RNN)")
plt.plot(np.arange(opt["numEpoch"]), lstmTestAccList, label="Test Accuracy (LSTM)")
plt.plot(np.arange(opt["numEpoch"]), gruTestAccList, label="Test Accuracy (GRU)")
plt.legend(loc="best")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("[Test Accuracy] RNN vs. LSTM vs. GRU")
plt.show()
